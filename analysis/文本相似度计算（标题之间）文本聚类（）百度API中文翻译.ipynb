# %% [markdown]
# # 原始想法
# idea: 很多paper开头都是 structure basis of xxxx...  (解结构的文章)
# biosynthesis of xxxx .... (老老实实生物合成的文章)

# %%
import pandas as pd

# %% [markdown]
# # 拿到数据

# %%
titles = pd.read_csv('../data/acs_catal_2020.tsv', sep='\t')['TI']
titles
# Out:
# 0       Revealing the Impact of Electrolyte Compositio...
# 1       Coupling Conversion of n-Hexane and CO over an...
# 2       Kinetic Isotope Effects: Interpretation and Pr...
# 3       Atomic Scale Insight into the Formation, Size,...
# 4       Active and Stable Pt-Ni Alloy Octahedra Cataly...
#                               ...
# 1420    Surface Species in Photocatalytic Methanol Ref...
# 1421    Highly Selective Reduction of CO2 to C2+ Hydro...
# 1422    Reaction Mechanism of Vapor-Phase Formic Acid ...
# 1423    Effects of Particle Size on Strong Metal-Suppo...
# 1424    Enzyme-Mediated Two-Step Regio- and Stereosele...
# Name: TI, Length: 1425, dtype: object

# %%
import requests
import random
import json
from hashlib import md5

def translate_baidu_api(query):
    """
    1. 拼接请求参数: appid + query + salt + 密钥 = 字符串1
    2. 对字符串1做md5
    (1. 带翻文本query需为UTF-8编码)
    
    """    
    # Set your own appid/appkey.
    appid = '20210413000775736'    # 填写你的appid
    appkey = '0WQhk5ub_ORT0VI_GlQe'    # 填写你的密钥

    # For list of language codes, please refer to `https://api.fanyi.baidu.com/doc/21`
    from_lang = 'en'
    to_lang =  'zh'

    endpoint = 'http://api.fanyi.baidu.com'
    path = '/api/trans/vip/translate'
    url = endpoint + path

#     query = 'Hello World! This is 1st paragraph.\nThis is 2nd paragraph.'

    # Generate salt and sign
    def make_md5(s, encoding='utf-8'):
        return md5(s.encode(encoding)).hexdigest()

    salt = random.randint(32768, 65536)
    sign = make_md5(appid + query + str(salt) + appkey)

    # Build request
    headers = {'Content-Type': 'application/x-www-form-urlencoded'}
    payload = {'appid': appid, 'q': query, 'from': from_lang, 'to': to_lang, 'salt': salt, 'sign': sign}

    # Send request
    r = requests.post(url, params=payload, headers=headers)
    result = r.json()
    # Show response
#     print(json.dumps(result, indent=4, ensure_ascii=False))['trans_result'][0]['dst']
    return result['trans_result'][0]['dst']
#     return json.dumps(result, indent=4, ensure_ascii=False)
#     return chineses_text
text = translate_baidu_api('Revealing the Impact of Electrolyte Composition for Co-Based Water Oxidation Catalysts by the Study of Reaction Kinetics Parameters')
text
# Out:
# '通过反应动力学参数的研究揭示电解质组成对Co基水氧化催化剂的影响'

# %%
for i in titles:
    print(i)
    print(translate_baidu_api(i))
    print("-"*100)
# Out:
# Revealing the Impact of Electrolyte Composition for Co-Based Water Oxidation Catalysts by the Study of Reaction Kinetics Parameters
# 通过反应动力学参数的研究揭示电解质组成对Co基水氧化催化剂的影响
# ----------------------------------------------------------------------------------------------------
# Coupling Conversion of n-Hexane and CO over an HZSM-5 Zeolite: Tuning the H/C Balance and Achieving High Aromatic Selectivity
# 正己烷和CO在HZSM-5沸石上的偶联转化：调节H/C平衡并实现高芳烃选择性
# ----------------------------------------------------------------------------------------------------
# Kinetic Isotope Effects: Interpretation and Prediction Using Degrees of Rate Control
# 动力学同位素效应：使用速率控制度的解释和预测
# ----------------------------------------------------------------------------------------------------
# Atomic Scale Insight into the Formation, Size, and Location of Platinum Nanoparticles Supported on gamma-Alumina
# 对γ-氧化铝支撑的铂纳米颗粒的形成、大小和位置的原子级洞察
# ...

# %% [markdown]
# # 想法实现：文本相似度

# %% [markdown]
# # 更进一步：文本聚类

# %% [markdown]
# 基本上把理论付诸实践了
# 1. 你去看数据。（structure basis of xxxx 是paper中才有的模式）（看数据=看论文）
# 2.
