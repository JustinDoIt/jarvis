# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

import sys
sys.path.append('../')
from translate import translate_baidu_api

# %%
def print_(texts, msg=''):
    print(f"{msg}相关文献共有{len(texts)}篇")
    print('-'*60)
    for text in texts:
        print(text)
        print(translate_baidu_api(text))
        print('-'*60)

# %% [markdown]
# # 数据

# %%
titles = pd.read_csv('../../data/csv-Bioinforma-set.csv')['Title']
# print(f"2021年Bioinformatics发文数量：{len(titles)}")
print_(transcrip_papers)
# Out:
# 相关文献共有40篇
# stPlus: a reference-based method for the accurate enhancement of spatial transcriptomics
# stPlus：一种精确增强空间转录组学的参考方法
# ------------------------------------------------------------
# Statistical approaches for differential expression analysis in metatranscriptomics
# 转录组学差异表达分析的统计方法
# ------------------------------------------------------------
# A comparison of rule-based and centroid single-sample multiclass predictors for transcriptomic classification
# 转录组分类中基于规则和质心的单样本多类预测因子的比较
# ------------------------------------------------------------
# Phylotranscriptomic patterns of network stochasticity and pathway dynamics during embryogenesis
# 胚胎发生过程中网络随机性和路径动力学的系统转录组学模式
# ------------------------------------------------------------
# Differential transcript usage analysis of bulk and single-cell RNA-seq data with DTUrtle
# 用DTUrtle分析批量和单细胞RNA序列数据的差异转录本使用情况
# ------------------------------------------------------------
# ...

# %%
all_papers = {
    "database" : [title for title in titles if re.findall('database*', title)], # 40
    "RNA-seq" : [title for title in titles if re.findall('RNA-seq*', title)],   # 36
    "transcrip*" : [title for title in titles if re.findall('transcrip*', title)], # 40
    "solub" : [title for title in titles if re.findall('solub', title)], # 2
    "stabil" : [title for title in titles if re.findall('stabil', title)], # 7
    "protein" : [title for title in titles if re.findall('protein', title)], # 104
    "feature" : [title for title in titles if re.findall('feature', title)],
    "Structur" : 
    "Secondary Structur" : 
}

# %%
Structur = [title for title in titles if re.findall('Structur', title)]
print_(Structur)
# Out:
# 相关文献共有26篇
# XRRpred: Accurate Predictor of Crystal Structure Quality from Protein Sequence
# XRRpred：从蛋白质序列准确预测晶体结构质量
# ------------------------------------------------------------
# Socket2: A Program for Locating, Visualising, and Analysing Coiled-coil Interfaces in Protein Structures
# Socket2：一个用于定位、可视化和分析蛋白质结构中螺旋线圈界面的程序
# ------------------------------------------------------------
# tSFM 1.0: tRNA Structure-Function Mapper
# tSFM 1.0:tRNA结构-功能映射器
# ------------------------------------------------------------
# Structure-aware protein-protein interaction site prediction using deep graph convolutional network
# 基于深度图卷积网络的结构感知蛋白质相互作用位点预测
# ------------------------------------------------------------
# Accelerating Big Data Quantitative Structure-Activity Prediction through LASSO-Random Forest Algorithm
# 利用LASSO随机森林算法加速大数据定量结构活动预测
# ------------------------------------------------------------
# Structural discrimination analysis for constraint selection in protein modeling
# ...
